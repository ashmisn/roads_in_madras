# %%
import pandas as pd
import sys
import os

# --- This is a trick to make the notebook find your 'src' folder ---
# It adds the project's root directory to the Python path
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)
# -----------------------------------------------------------------

# Now you can import your config file
from src import config

print(f"Loading dataset from: {config.RAW_DATA_PATH}")

# Load your raw dataset
try:
    df = pd.read_csv(config.RAW_DATA_PATH)
except FileNotFoundError:
    print("\n---")
    print(f"ERROR: File not found at {config.RAW_DATA_PATH}")
    print("Please make sure your 'GPT_Input_DB(Sheet1).csv' file is in the 'data/raw/' folder.")
    print("---")
# Out:
# Loading dataset from: /home/joelphilip/Documents/roads-in-madras/data/raw/GPT_Input_DB(Sheet1).csv

# %%
# Show the first 5 rows
df.head()
# Out:
#    S. No.             problem   category                      type  \
# 0       1             Damaged  Road Sign                 STOP Sign
# 1       2        Height Issue  Road Sign  Minimum Speed Limit Sign
# 2       3               Faded  Road Sign             Hospital Sign
# 3       4       Spacing Issue  Road Sign         U-Turn Ahead Sign
# 4       5  Improper Placement  Road Sign        Gap in Median Sign
#
#                                                 data         code   clause
# 0  The 'STOP' sign, used on Minor Roads intersect...  IRC:67-2022     14.4
# 1  Minimum Speed Limit Sign shall be installed to...  IRC:67-2022  14.10.6
# 2  Hospital sign should be used to notify drivers...  IRC:67-2022     17.8
# 3  When multiple signs need to be placed along th...  IRC:67-2022      4.8
# 4  Gap in Median sign shall be installed ahead of...  IRC:67-2022    15.26

# %%
# Get a full summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   S. No.    50 non-null     int64
#  1   problem   50 non-null     object
#  2   category  50 non-null     object
#  3   type      50 non-null     object
#  4   data      50 non-null     object
#  5   code      50 non-null     object
#  6   clause    50 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 2.9+ KB

# %%
# What are all the unique 'problem' types?
print("--- Problems ---")
print(df['problem'].value_counts())

# What are all the unique 'category' types?
print("\n--- Categories ---")
print(df['category'].value_counts())

# What are all the unique 'type' types?
print("\n--- Types ---")
print(df['type'].value_counts())
# Out:
# --- Problems ---
# problem
# Missing                   11
# Damaged                    6
# Faded                      6
# Non-Standard               5
# Placement Issue            5
# Spacing Issue              3
# Wrong Colour Selection     3
# Height Issue               2
# Obstruction                2
# Wrongly Placed             2
# Visibility Issue           2
# Improper Placement         1
# Non-Retroreflective        1
# Non-Retro Reflective       1
# Name: count, dtype: int64
#
# --- Categories ---
# category
# Road Sign                   20
# Road Marking                20
# Traffic Calming Measures    10
# Name: count, dtype: int64
#
# --- Types ---
# type
# Speed Hump                                         3
# Transverse Bar Marking                             3
# STOP Sign                                          2
# U-Turn Ahead Sign                                  2
# Rumble Strip                                       2
# ...
